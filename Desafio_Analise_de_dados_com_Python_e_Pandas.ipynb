# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("bmh")

# %%
from google.colab import files
arq = files.upload()
# Out:
#      <input type="file" id="files-3be148d3-57d4-4989-ac16-3426d8991e0c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3be148d3-57d4-4989-ac16-3426d8991e0c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("dataanime.csv")

# %%
df.head()
# Out:
#                               Title   Type Episodes            Status  \
# 0  Fullmetal Alchemist: Brotherhood     TV       64   Finished Airing
# 1                    Kimi no Na wa.  Movie        1   Finished Airing
# 2                          Gintama°     TV       51   Finished Airing
# 3                     Steins;Gate 0     TV       23  Currently Airing
# 4                       Steins;Gate     TV       24   Finished Airing
#
#   Start airing End airing Starting season             Broadcast time  \
# 0     2009-4-5   2010-7-4          Spring     Sundays at 17:00 (JST)
# 1    2016-8-26          -               -                          -
# 2     2015-4-8  2016-3-30          Spring  Wednesdays at 18:00 (JST)
# 3    2018-4-12          -          Spring   Thursdays at 01:35 (JST)
# 4     2011-4-6  2011-9-14          Spring  Wednesdays at 02:05 (JST)
#
#                                            Producers  \
# 0  Aniplex,Square Enix,Mainichi Broadcasting Syst...
# ...

# %%
df = df.rename(columns={"Title":"Titulo","Type":"Tipo","Episodes":"Episodios","Status":"Estado","Start airing":"Começo da exibição","End airing":"Fim da exibição","Starting season":"Temporada inicial","Broadcast time":"Tempo de transmissão","Producers":"Produtores", "Licensors":"Licenciadores", "Studios":"Estúdios","Sources":"Fontes","Genres":"Generos","Rating":"Classificação", "Score":"Pontuação","Scored by":"Marcados por","Members":"Membros","Favorites":"Favoritos","Description":"Descrição"})

# %%
df.head(3)
# Out:
#                              Titulo   Tipo Episodios           Estado  \
# 0  Fullmetal Alchemist: Brotherhood     TV        64  Finished Airing
# 1                    Kimi no Na wa.  Movie         1  Finished Airing
# 2                          Gintama°     TV        51  Finished Airing
#
#   Começo da exibição Fim da exibição Temporada inicial  \
# 0           2009-4-5        2010-7-4            Spring
# 1          2016-8-26               -                 -
# 2           2015-4-8       2016-3-30            Spring
#
#         Tempo de transmissão  \
# 0     Sundays at 17:00 (JST)
# 1                          -
# 2  Wednesdays at 18:00 (JST)
#
#                                           Produtores  \
# 0  Aniplex,Square Enix,Mainichi Broadcasting Syst...
# 1  Kadokawa Shoten,Toho,Sound Team Don Juan,Lawso...
# 2                            TV Tokyo,Aniplex,Dentsu
#
#                    Licenciadores               Estúdios    Fontes  \
# ...

# %%
df.shape
# Out:
# (1563, 20)

# %%
df.dtypes
# Out:
# Titulo                   object
# Tipo                     object
# Episodios                object
# Estado                   object
# Começo da exibição       object
# Fim da exibição          object
# Temporada inicial        object
# Tempo de transmissão     object
# Produtores               object
# Licenciadores            object
# Estúdios                 object
# Fontes                   object
# Generos                  object
# Duration                 object
# Classificação            object
# Pontuação               float64
# Marcados por              int64
# Membros                   int64
# Favoritos                 int64
# Descrição                object
# dtype: object

# %%
df.describe()
# Out:
#          Pontuação   Marcados por       Membros     Favoritos
# count  1563.000000    1563.000000  1.563000e+03    1563.00000
# mean      7.905144   60537.209213  1.153567e+05    2309.15483
# std       0.340127   99856.869169  1.669685e+05    7358.06195
# min       7.480000     144.000000  7.810000e+02       1.00000
# 25%       7.630000    6876.000000  1.738050e+04      54.00000
# 50%       7.820000   24730.000000  5.209700e+04     264.00000
# 75%       8.110000   68933.500000  1.367520e+05    1273.00000
# max       9.250000  993775.000000  1.432871e+06  105387.00000

# %%
df.nlargest(3, "Pontuação")
# Out:
#                              Titulo   Tipo Episodios           Estado  \
# 0  Fullmetal Alchemist: Brotherhood     TV        64  Finished Airing
# 1                    Kimi no Na wa.  Movie         1  Finished Airing
# 2                          Gintama°     TV        51  Finished Airing
#
#   Começo da exibição Fim da exibição Temporada inicial  \
# 0           2009-4-5        2010-7-4            Spring
# 1          2016-8-26               -                 -
# 2           2015-4-8       2016-3-30            Spring
#
#         Tempo de transmissão  \
# 0     Sundays at 17:00 (JST)
# 1                          -
# 2  Wednesdays at 18:00 (JST)
#
#                                           Produtores  \
# 0  Aniplex,Square Enix,Mainichi Broadcasting Syst...
# 1  Kadokawa Shoten,Toho,Sound Team Don Juan,Lawso...
# 2                            TV Tokyo,Aniplex,Dentsu
#
#                    Licenciadores               Estúdios    Fontes  \
# ...

# %%
#nsmallest
df.nsmallest(3, "Pontuação")
# Out:
#                                  Titulo     Tipo Episodios           Estado  \
# 1521  Aishen Qiaokeli-ing... 2nd Season      ONA        15  Finished Airing
# 1548                        Yao Shen Ji      ONA        40  Finished Airing
# 1550                 Beelzebub Specials  Special        16  Finished Airing
#
#      Começo da exibição Fim da exibição Temporada inicial  \
# 1521         2017-12-21        2018-4-5                 -
# 1548           2017-5-9       2017-9-22                 -
# 1550          2011-6-29       2012-9-26                 -
#
#      Tempo de transmissão                  Produtores Licenciadores  \
# 1521                    -  Tencent Animation,bilibili             -
# 1548                    -                           -             -
# 1550                    -                 Opera House             -
#
#                          Estúdios     Fontes  \
# 1521      G.CMay Animation & Film  Web manga
# 1548                            -      Novel
# ...

# %%
df.groupby("Estúdios")["Favoritos"].sum().sort_values(ascending=False).head(5)
# Out:
# Estúdios
# Madhouse           339086
# Bones              305964
# Sunrise            261364
# A-1 Pictures       235052
# Kyoto Animation    214378
# Name: Favoritos, dtype: int64

# %%
df.groupby("Estúdios")["Favoritos"].sum().sort_values(ascending=False).head(5).plot.barh(title="Ranking de Estúdios por Popularidade")
plt.xlabel("Total de favoritos")
plt.ylabel("Estudios");

# %%
filtro = df.loc[(df["Generos"].str.contains('Supernatural', case=False, na=False)) & (df['Pontuação'] > 8)]

# %%
filtro.sample(4)
# Out:
#                                                 Titulo   Tipo Episodios  \
# 147  Fate/stay night: Unlimited Blade Works 2nd Season     TV        13
# 71                             Boku dake ga Inai Machi     TV        12
# 61                      Kara no Kyoukai 5: Mujun Rasen  Movie         1
# 229      Saint Seiya: The Lost Canvas - Meiou Shinwa 2    OVA        13
#
#               Estado Começo da exibição Fim da exibição Temporada inicial  \
# 147  Finished Airing           2015-4-5       2015-6-28            Spring
# 71   Finished Airing           2016-1-8       2016-3-25            Winter
# 61   Finished Airing          2008-8-16               -                 -
# 229  Finished Airing          2011-2-23       2011-7-20                 -
#
#        Tempo de transmissão  \
# 147  Sundays at 00:00 (JST)
# 71   Fridays at 00:55 (JST)
# 61                        -
# 229                       -
#
#                                             Produtores       Licenciadores  \
# ...

# %%
df["Classificação"].value_counts(ascending=False)
# Out:
# PG-13    1040
# R         314
# G         140
# PG         60
# None        9
# Name: Classificação, dtype: int64

# %%
df["Classificação"].value_counts(ascending=False).plot.barh(title="Titulos por Classificação")
# Out:
# <Axes: title={'center': 'Titulos por Classificação'}>
